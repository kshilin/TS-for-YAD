# %%
import numpy as np
import pandas as pd

#pip install yfinance
import yfinance as yf

import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display
import datetime

print(pd.__version__)
print(sns.__version__)
print(yf.__version__)
# Out:
# 2.3.1
# 0.13.2
# 0.2.66

# %%
# start = datetime.datetime(2015, 1, 1)
# end = datetime.datetime(2020, 12, 31)

symbol=['NKE','MSFT','AAPL','CVX','IBM','AXP']

# %%
df = yf.download( symbol, start='2008-1-1', end='2009-12-31')
df
# Out:
# /var/folders/yr/lbn9q2ts2kv3nbc69_l3nscm0000gp/T/ipykernel_74696/735549532.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download( symbol, start='2008-1-1', end='2009-12-31')
# [*********************100%***********************]  6 of 6 completed
# Price          Close                                                         \
# Ticker          AAPL        AXP        CVX        IBM       MSFT        NKE
# Date
# 2008-01-02  5.843454  38.702679  46.042694  55.506992  25.252069  12.486480
# 2008-01-03  5.846156  38.224937  46.609226  55.618328  25.359619  12.373999
# 2008-01-04  5.399885  37.261932  45.988514  53.619476  24.649801  12.182606
# 2008-01-07  5.327610  37.428761  45.387459  53.046867  24.814705  12.255610
# 2008-01-08  5.135967  36.359573  44.806137  51.742550  23.983004  12.200363
# ...              ...        ...        ...        ...        ...        ...
# 2009-12-23  6.061190  32.786186  40.604465  71.533379  23.107637  13.369449
# 2009-12-24  6.269326  33.160122  40.810024  71.847031  23.167418  13.330634
# 2009-12-28  6.346406  32.658905  40.989227  72.804443  23.294470  13.381705
# 2009-12-29  6.271128  32.523647  40.694057  72.551346  23.458878  13.526757
# 2009-12-30  6.347302  32.460011  40.925976  72.947510  23.137529  13.512460
#
# Price           High                                   ...       Open  \
# Ticker          AAPL        AXP        CVX        IBM  ...        CVX
# Date                                                   ...
# 2008-01-02  6.006006  39.673278  46.648650  57.786864  ...  46.289017
# 2008-01-03  5.919934  39.051464  46.722533  55.973567  ...  46.210184
# 2008-01-04  5.788269  37.906473  46.904836  55.114650  ...  46.249616
# 2008-01-07  5.506356  37.989887  46.180619  53.550563  ...  46.180619
# 2008-01-08  5.472167  37.686565  46.003267  53.221818  ...  45.525403
# ...              ...        ...        ...        ...  ...        ...
# 2009-12-23  6.069587  33.287408  41.073546  71.533379  ...  41.041924
# 2009-12-24  6.278624  33.176034  40.846918  71.847031  ...  40.593929
# 2009-12-28  6.416585  33.247642  41.057747  72.804443  ...  40.994499
# 2009-12-29  6.379696  32.818014  41.078811  72.837479  ...  41.010291
# 2009-12-30  6.358100  32.483880  40.936515  73.008039  ...  40.636093
#
# Price                                            Volume                      \
# Ticker            IBM       MSFT        NKE        AAPL       AXP       CVX
# Date
# 2008-01-02  57.786864  25.660748  12.691694  1079178800   8053700   9058000
# 2008-01-03  55.581216  25.252074  12.486472   842066400   7753200  10479200
# 2008-01-04  55.114650  25.230554  12.281266  1455832000   8501400  13103800
# 2008-01-07  53.152910  24.771685  12.233904  2072193200  14031100  12892200
# 2008-01-08  53.046849  24.886398  12.312836  1523816000  11721000  10987700
# ...               ...        ...        ...         ...       ...       ...
# 2009-12-23  71.368303  22.950696  13.293857   345525600   5296400   7342600
# 2009-12-24  71.472853  23.077737  13.369452   500889200   2070000   2565500
# 2009-12-28  72.078106  23.167423  13.330630   644565600   5369900   4192800
# 2009-12-29  72.787955  23.428985  13.381704   445205600   4438200   4810600
# 2009-12-30  72.210168  23.279524  13.453212   412084400   3557100   4300800
#
# Price
# Ticker           IBM      MSFT       NKE
# Date
# 2008-01-02   9940661  63004200   9781600
# 2008-01-03   7875229  49599600  10636000
# 2008-01-04  11542192  72090800  22335200
# 2008-01-07  13232318  80164300  20808400
# 2008-01-08   9868382  79148300  16714400
# ...              ...       ...       ...
# 2009-12-23   4317470  28362700   6148400
# 2009-12-24   4461295  11083900   2302000
# 2009-12-28   6067218  25384000   5648000
# 2009-12-29   4376673  29716200   8083200
# 2009-12-30   4044882  42006200   6932000
#
# [504 rows x 30 columns]

# %%
df.columns
# Out:
# MultiIndex([( 'Close', 'AAPL'),
#             ( 'Close',  'AXP'),
#             ( 'Close',  'CVX'),
#             ( 'Close',  'IBM'),
#             ( 'Close', 'MSFT'),
#             ( 'Close',  'NKE'),
#             (  'High', 'AAPL'),
#             (  'High',  'AXP'),
#             (  'High',  'CVX'),
#             (  'High',  'IBM'),
#             (  'High', 'MSFT'),
#             (  'High',  'NKE'),
#             (   'Low', 'AAPL'),
#             (   'Low',  'AXP'),
#             (   'Low',  'CVX'),
#             (   'Low',  'IBM'),
#             (   'Low', 'MSFT'),
#             (   'Low',  'NKE'),
#             (  'Open', 'AAPL'),
#             (  'Open',  'AXP'),
#             (  'Open',  'CVX'),
#             (  'Open',  'IBM'),
#             (  'Open', 'MSFT'),
#             (  'Open',  'NKE'),
#             ('Volume', 'AAPL'),
#             ('Volume',  'AXP'),
#             ('Volume',  'CVX'),
#             ('Volume',  'IBM'),
#             ('Volume', 'MSFT'),
#             ('Volume',  'NKE')],
#            names=['Price', 'Ticker'])

# %%
df['Open']
# Out:
# Ticker          AAPL        AXP        CVX        IBM       MSFT        NKE
# Date
# 2008-01-02  5.976315  39.498873  46.289017  57.786864  25.660748  12.691694
# 2008-01-03  5.860552  38.823980  46.210184  55.581216  25.252074  12.486472
# 2008-01-04  5.741783  37.906473  46.249616  55.114650  25.230554  12.281266
# 2008-01-07  5.435877  37.557667  46.180619  53.152910  24.771685  12.233904
# 2008-01-08  5.402587  37.686565  45.525403  53.046849  24.886398  12.312836
# ...              ...        ...        ...        ...        ...        ...
# 2009-12-23  6.034197  33.096465  41.041924  71.368303  22.950696  13.293857
# 2009-12-24  6.104676  32.897576  40.593929  71.472853  23.077737  13.369452
# 2009-12-28  6.349705  33.168081  40.994499  72.078106  23.167423  13.330630
# 2009-12-29  6.376997  32.627072  41.010291  72.787955  23.428985  13.381704
# 2009-12-30  6.263028  32.300892  40.636093  72.210168  23.279524  13.453212
#
# [504 rows x 6 columns]

# %%
stoks_close = df['Close']
stoks_close.head(5)
# Out:
# Ticker          AAPL        AXP        CVX        IBM       MSFT        NKE
# Date
# 2008-01-02  5.843454  38.702679  46.042694  55.506992  25.252069  12.486480
# 2008-01-03  5.846156  38.224937  46.609226  55.618328  25.359619  12.373999
# 2008-01-04  5.399885  37.261932  45.988514  53.619476  24.649801  12.182606
# 2008-01-07  5.327610  37.428761  45.387459  53.046867  24.814705  12.255610
# 2008-01-08  5.135967  36.359573  44.806137  51.742550  23.983004  12.200363

# %%
stoks_volume = df['Volume']
stoks_volume.head(5)
# Out:
# Ticker            AAPL       AXP       CVX       IBM      MSFT       NKE
# Date
# 2008-01-02  1079178800   8053700   9058000   9940661  63004200   9781600
# 2008-01-03   842066400   7753200  10479200   7875229  49599600  10636000
# 2008-01-04  1455832000   8501400  13103800  11542192  72090800  22335200
# 2008-01-07  2072193200  14031100  12892200  13232318  80164300  20808400
# 2008-01-08  1523816000  11721000  10987700   9868382  79148300  16714400

# %%
stoks_close.plot();

# %%
stoks_close['AAPL'].plot();

# %%
plt.bar(stoks_volume['AAPL'].index,stoks_volume['AAPL'].values, color ='b');

# %%
# Здесь разбираемся сами и совмещаем два графика

# %% [markdown]
# ### Вычисляем ежедневное процентное закрытие
# $$ r_t =\dfrac{p_t}{p_{t-1}}-1 $$

# %%
daily_pct_na=(stoks_close/stoks_close.shift(1)-1)
daily_pct_na.head()
# Out:
# Ticker          AAPL       AXP       CVX       IBM      MSFT       NKE
# Date
# 2008-01-02       NaN       NaN       NaN       NaN       NaN       NaN
# 2008-01-03  0.000462 -0.012344  0.012304  0.002006  0.004259 -0.009008
# 2008-01-04 -0.076336 -0.025193 -0.013317 -0.035939 -0.027990 -0.015467
# 2008-01-07 -0.013385  0.004477 -0.013070 -0.010679  0.006690  0.005992
# 2008-01-08 -0.035972 -0.028566 -0.012808 -0.024588 -0.033516 -0.004508

# %%
#тут внимательнее с данными
daily_pct_0=(stoks_close/stoks_close.shift(1)-1).fillna(0)
daily_pct_0.head()
# Out:
# Ticker          AAPL       AXP       CVX       IBM      MSFT       NKE
# Date
# 2008-01-02  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2008-01-03  0.000462 -0.012344  0.012304  0.002006  0.004259 -0.009008
# 2008-01-04 -0.076336 -0.025193 -0.013317 -0.035939 -0.027990 -0.015467
# 2008-01-07 -0.013385  0.004477 -0.013070 -0.010679  0.006690  0.005992
# 2008-01-08 -0.035972 -0.028566 -0.012808 -0.024588 -0.033516 -0.004508

# %% [markdown]
# ### Вычисляем кумулятивную процентную доходность
# $$ i_0=r_0=0 $$
# $$ i_t=(i_{t-1}+r_t)100 $$

# %%
daily_sum_na=(daily_pct_na*100).cumsum()
daily_sum_na.head(5)
# Out:
# Ticker           AAPL       AXP       CVX       IBM      MSFT       NKE
# Date
# 2008-01-02        NaN       NaN       NaN       NaN       NaN       NaN
# 2008-01-03   0.046227 -1.234388  1.230450  0.200580  0.425904 -0.900823
# 2008-01-04  -7.587344 -3.753699 -0.101287 -3.393293 -2.373104 -2.447558
# 2008-01-07  -8.925810 -3.305982 -1.408255 -4.461205 -1.704118 -1.848312
# 2008-01-08 -12.522972 -6.162574 -2.689053 -6.920007 -5.055765 -2.299096

# %%
daily_sum_0=(daily_pct_0*100).cumsum()
daily_sum_0.head(5)
# Out:
# Ticker           AAPL       AXP       CVX       IBM      MSFT       NKE
# Date
# 2008-01-02   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2008-01-03   0.046227 -1.234388  1.230450  0.200580  0.425904 -0.900823
# 2008-01-04  -7.587344 -3.753699 -0.101287 -3.393293 -2.373104 -2.447558
# 2008-01-07  -8.925810 -3.305982 -1.408255 -4.461205 -1.704118 -1.848312
# 2008-01-08 -12.522972 -6.162574 -2.689053 -6.920007 -5.055765 -2.299096

# %%
daily_sum_0.plot();

# %% [markdown]
# ### Вычисляем накопленную процентную доходность
# $$ i_0 = 1 $$
# $$ i_t = (1+r_t) i_{t-1} $$

# %%
daily_prod_na=(1 + daily_pct_na).cumprod()
daily_prod_na.head(5)
# Out:
# Ticker          AAPL       AXP       CVX       IBM      MSFT       NKE
# Date
# 2008-01-02       NaN       NaN       NaN       NaN       NaN       NaN
# 2008-01-03  1.000462  0.987656  1.012304  1.002006  1.004259  0.990992
# 2008-01-04  0.924091  0.962774  0.998823  0.965995  0.976150  0.975664
# 2008-01-07  0.911723  0.967084  0.985769  0.955679  0.982680  0.981510
# 2008-01-08  0.878926  0.939459  0.973143  0.932181  0.949744  0.977086

# %%
daily_prod_0=(1 + daily_pct_0).cumprod()
daily_prod_0.head(5)
# Out:
# Ticker          AAPL       AXP       CVX       IBM      MSFT       NKE
# Date
# 2008-01-02  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# 2008-01-03  1.000462  0.987656  1.012304  1.002006  1.004259  0.990992
# 2008-01-04  0.924091  0.962774  0.998823  0.965995  0.976150  0.975664
# 2008-01-07  0.911723  0.967084  0.985769  0.955679  0.982680  0.981510
# 2008-01-08  0.878926  0.939459  0.973143  0.932181  0.949744  0.977086

# %%
daily_prod_0.plot();

# %%
daily_prod_0.asfreq(freq='ME')
# Out:
# Ticker          AAPL       AXP       CVX       IBM      MSFT       NKE
# Date
# 2008-01
# 2008-12-01  0.456426  0.389954  0.794071  0.747411  0.538143  0.767168
# 2009-01-01  0.465767  0.383799  0.843687  0.849172  0.587880  0.851782
# 2009-02-01  0.469668  0.340045  0.774997  0.883772  0.515588  0.713243
# 2009-03-01  0.451345  0.221490  0.641150  0.870208  0.459728  0.638274
# 2009-04-01  0.557843  0.293048  0.759988  0.953858  0.562214  0.758958
# 2009-05-01  0.653049  0.492946  0.744076  1.022263  0.589291  0.854555
# 2009-06-01  0.715202  0.527446  0.777563  1.064538  0.627021  0.956934
# 2009-07-01  0.733063  0.470294  0.747341  1.029862  0.704373  0.850135
# 2009-08-01  0.854188  0.585822  0.790932  1.177996  0.698220  0.918249
# 2009-09-01  0.848389  0.653913  0.777060  1.151613  0.707155  0.881597
# 2009-10-01  0.928249  0.667261  0.780805  1.163555  0.733084  1.018385
# 2009-11-01  0.971618  0.733453  0.869654  1.189806  0.821479  1.018385
# 2009-12-01  1.010932  0.848980  0.905010  1.268306  0.888147  1.065639

# %%
month_prod.plot();

# %% [markdown]
# ### Скользящее среднее

# %%
aapl_close=stoks_close['IBM']
ma_30=aapl_close.rolling(30).mean()
ma_90=aapl_close.rolling(90).mean()
result=pd.concat([aapl_close,ma_30,ma_90],axis=1)
result.columns=['IBM','ma_30','ma_90']
result.plot();

# %%
aapl_close=daily_sum_0['AAPL']
msft_close=daily_sum_0['MSFT']

# %%
plt.scatter(aapl_close,aapl_close);

# %%
plt.scatter(aapl_close,msft_close);

# %%
df=pd.concat([aapl_close,msft_close],axis=1)
sns.scatterplot(x="AAPL", y="MSFT",data=df);

# %%
sns.residplot( x = aapl_close, y = msft_close, lowess=True, color="g");

# %%
sns.jointplot(x="AAPL", y="MSFT", data=df, kind="reg", color="m", height=7);

# %% [markdown]
# ### Волатильность

# %%
per=30

vol=daily_pct_0.rolling(per).std()*np.sqrt(per)
vol.plot();

# %% [markdown]
# ### Оценим риск

# %%
df_risk=pd.concat([daily_pct_0.mean(),daily_pct_0.std()],axis=1)
df_risk.columns=["mean",'std']
df_risk
# Out:
#             mean       std
# Ticker
# AAPL    0.000622  0.030187
# AXP     0.000728  0.046675
# CVX     0.000150  0.027852
# IBM     0.000747  0.020285
# MSFT    0.000195  0.027289
# NKE     0.000526  0.027283

# %%
sns.scatterplot(x="mean", y="std",data=df_risk,hue=df_risk.index)
# Out:
# <Axes: xlabel='mean', ylabel='std'>

# %% [markdown]
# ### Взаимная корреляция
#
# напомним про клику и диверсификацию портфеля

# %%
corr=daily_pct_0.corr()
corr
# Out:
# Ticker      AAPL       AXP       CVX       IBM      MSFT       NKE
# Ticker
# AAPL    1.000000  0.548965  0.533640  0.587965  0.555598  0.511044
# AXP     0.548965  1.000000  0.586455  0.578018  0.593987  0.596009
# CVX     0.533640  0.586455  1.000000  0.627706  0.647862  0.542540
# IBM     0.587965  0.578018  0.627706  1.000000  0.618611  0.625598
# MSFT    0.555598  0.593987  0.647862  0.618611  1.000000  0.532699
# NKE     0.511044  0.596009  0.542540  0.625598  0.532699  1.000000

# %%
sns.heatmap(corr, annot=True);

# %%
from matplotlib import cm
cmap = cm.coolwarm
#np.fill_diagonal(corr.values, np.nan)
np.fill_diagonal(corr.values, 0)
sns.heatmap(corr, annot=True, vmin=-1, vmax=1, cmap=cmap);
